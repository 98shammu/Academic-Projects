# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns

# %% [markdown]
# ## Answer the below questions -
# ## 1. Reading the Rounds2, companies.txt files?

# %%
companies=pd.read_csv(r'C:\Users\telsm\Documents\datascience\data science\course files\miniprojects\Project 2-2-1 python\Project 2\Dataset\companies (1).txt',sep='\t')
companies
# Out:
#                                                permalink  \
# 0                                    /Organization/-Fame
# 1                                 /Organization/-Qounter
# 2                    /Organization/-The-One-Of-Them-Inc-
# 3                                  /Organization/0-6-Com
# 4                         /Organization/004-Technologies
# ...                                                  ...
# 66363  /Organization/Zznode-Science-And-Technology-Co...
# 66364                          /Organization/Zzzzapp-Com
# 66365                               /Organization/ÃEron
# 66366                             /Organization/Ã”Asys-2
# 66367  /Organization/Ä°Novatiff-Reklam-Ve-Tanä±Tä±M-H...
#
#                                                 name  \
# 0                                              #fame
# 1                                           :Qounter
# 2                             (THE) ONE of THEM,Inc.
# 3                                            0-6.com
# ...

# %%
companies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66368 entries, 0 to 66367
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   permalink      66368 non-null  object
#  1   name           66367 non-null  object
#  2   homepage_url   61310 non-null  object
#  3   category_list  63220 non-null  object
#  4   status         66368 non-null  object
#  5   country_code   59410 non-null  object
#  6   state_code     57821 non-null  object
#  7   region         58338 non-null  object
#  8   city           58340 non-null  object
#  9   founded_at     51147 non-null  object
# dtypes: object(10)
# memory usage: 5.1+ MB

# %%
companies.describe()
# Out:
#                   permalink   name                homepage_url category_list  \
# count                 66368  66367                       61310         63220
# unique                66368  66102                       61191         27296
# top     /Organization/-Fame  Blink  http://www.askforoffer.com      Software
# freq                      1      4                           5          3995
#
#            status country_code state_code       region           city  \
# count       66368        59410      57821        58338          58340
# unique          4          137        311         1092           5111
# top     operating          USA         CA  SF Bay Area  San Francisco
# freq        53034        37601      12900         8804           3526
#
#         founded_at
# count        51147
# unique        3978
# top     01-01-2012
# freq          2730

# %%
companies.isnull().sum()
# Out:
# permalink            0
# name                 1
# homepage_url      5058
# category_list     3148
# status               0
# country_code      6958
# state_code        8547
# region            8030
# city              8028
# founded_at       15221
# dtype: int64

# %%
# as the data set is fully categoriacl and multimodal we avoided treating the missing values.

# %%
round2=pd.read_csv(r"C:\Users\telsm\Documents\datascience\data science\course files\miniprojects\Project 2-2-1 python\Project 2\Dataset\rounds2 (1).csv", encoding='latin1')
round2.head(5)
# Out:
#                      company_permalink  \
# 0                  /organization/-fame
# 1               /ORGANIZATION/-QOUNTER
# 2               /organization/-qounter
# 3  /ORGANIZATION/-THE-ONE-OF-THEM-INC-
# 4                /organization/0-6-com
#
#                            funding_round_permalink funding_round_type  \
# 0  /funding-round/9a01d05418af9f794eebff7ace91f638            venture
# 1  /funding-round/22dacff496eb7acb2b901dec1dfe5633            venture
# 2  /funding-round/b44fbb94153f6cdef13083530bb48030               seed
# 3  /funding-round/650b8f704416801069bb178a1418776b            venture
# 4  /funding-round/5727accaeaa57461bd22a9bdd945382d            venture
#
#   funding_round_code   funded_at  raised_amount_usd
# 0                  B  05-01-2015         10000000.0
# 1                  A  14-10-2014                NaN
# 2                NaN  01-03-2014           700000.0
# 3                  B  30-01-2014          3406878.0
# ...

# %%
round2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114949 entries, 0 to 114948
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   company_permalink        114949 non-null  object
#  1   funding_round_permalink  114949 non-null  object
#  2   funding_round_type       114949 non-null  object
#  3   funding_round_code       31140 non-null   object
#  4   funded_at                114949 non-null  object
#  5   raised_amount_usd        94959 non-null   float64
# dtypes: float64(1), object(5)
# memory usage: 5.3+ MB

# %%
round2.describe()
# Out:
#        raised_amount_usd
# count       9.495900e+04
# mean        1.042687e+07
# std         1.148212e+08
# min         0.000000e+00
# 25%         3.225000e+05
# 50%         1.680511e+06
# 75%         7.000000e+06
# max         2.127194e+10

# %%
round2.describe(include='object')
# Out:
#                company_permalink  \
# count                     114949
# unique                     90247
# top     /ORGANIZATION/SOLARFLARE
# freq                          10
#
#                                 funding_round_permalink funding_round_type  \
# count                                            114949             114949
# unique                                           114949                 14
# top     /funding-round/9a01d05418af9f794eebff7ace91f638            venture
# freq                                                  1              55494
#
#        funding_round_code   funded_at
# count               31140      114949
# unique                  8        5033
# top                     A  01-01-2014
# freq                14747         779

# %%
round2.isnull().sum()
# Out:
# company_permalink              0
# funding_round_permalink        0
# funding_round_type             0
# funding_round_code         83809
# funded_at                      0
# raised_amount_usd          19990
# dtype: int64

# %%
## no null value treatment done here also.

# %% [markdown]
# # 2. How many unique companies are present in rounds2?

# %%
round2[~round2.duplicated('company_permalink')]['company_permalink'].count()
# Out:
# 90247

# %%
round2["company_permalink"].unique().size
# Out:
# 90247

# %% [markdown]
# # 3. How many unique companies are present in the companies file?

# %%
companies[~companies.duplicated('permalink')]['permalink'].count()
# Out:
# 66368

# %%
companies["permalink"].unique().size
# Out:
# 66368

# %% [markdown]
# ## 4.Write the code to convert companies[‘permalink’] and Round2[‘company_permalink’] columns to uppercase.

# %%
companies["permalink"]=companies["permalink"].str.upper()
companies.head()
# Out:
#                              permalink                    name  \
# 0                  /ORGANIZATION/-FAME                   #fame
# 1               /ORGANIZATION/-QOUNTER                :Qounter
# 2  /ORGANIZATION/-THE-ONE-OF-THEM-INC-  (THE) ONE of THEM,Inc.
# 3                /ORGANIZATION/0-6-COM                 0-6.com
# 4       /ORGANIZATION/004-TECHNOLOGIES        004 Technologies
#
#                         homepage_url  \
# 0                 http://livfame.com
# 1             http://www.qounter.com
# 2                http://oneofthem.jp
# 3                 http://www.0-6.com
# 4  http://004gmbh.de/en/004-interact
#
#                                        category_list     status country_code  \
# 0                                              Media  operating          IND
# 1  Application Platforms|Real Time|Social Network...  operating          USA
# 2                                  Apps|Games|Mobile  operating          NaN
# ...

# %%
round2["company_permalink"]=round2["company_permalink"].str.upper()
round2.head()
# Out:
#                      company_permalink  \
# 0                  /ORGANIZATION/-FAME
# 1               /ORGANIZATION/-QOUNTER
# 2               /ORGANIZATION/-QOUNTER
# 3  /ORGANIZATION/-THE-ONE-OF-THEM-INC-
# 4                /ORGANIZATION/0-6-COM
#
#                            funding_round_permalink funding_round_type  \
# 0  /funding-round/9a01d05418af9f794eebff7ace91f638            venture
# 1  /funding-round/22dacff496eb7acb2b901dec1dfe5633            venture
# 2  /funding-round/b44fbb94153f6cdef13083530bb48030               seed
# 3  /funding-round/650b8f704416801069bb178a1418776b            venture
# 4  /funding-round/5727accaeaa57461bd22a9bdd945382d            venture
#
#   funding_round_code   funded_at  raised_amount_usd
# 0                  B  05-01-2015         10000000.0
# 1                  A  14-10-2014                NaN
# 2                NaN  01-03-2014           700000.0
# 3                  B  30-01-2014          3406878.0
# ...

# %% [markdown]
# ## 5. Are there any companies in the rounds2 file which are not present in companies.txt ?

# %%
RnotinC=round2[~round2['company_permalink'].isin(companies['permalink'])]
RnotinC.head()
# Out:
#                      company_permalink  \
# 0                  /organization/-fame
# 2               /organization/-qounter
# 4                /organization/0-6-com
# 6     /organization/01games-technology
# 8  /organization/0ndine-biomedical-inc
#
#                            funding_round_permalink funding_round_type  \
# 0  /funding-round/9a01d05418af9f794eebff7ace91f638            venture
# 2  /funding-round/b44fbb94153f6cdef13083530bb48030               seed
# 4  /funding-round/5727accaeaa57461bd22a9bdd945382d            venture
# 6  /funding-round/7d53696f2b4f607a2f2a8cbb83d01839        undisclosed
# 8  /funding-round/954b9499724b946ad8c396a57a5f3b72            venture
#
#   funding_round_code   funded_at  raised_amount_usd
# 0                  B  05-01-2015         10000000.0
# 2                NaN  01-03-2014           700000.0
# 4                  A  19-03-2008          2000000.0
# 6                NaN  01-07-2014            41250.0
# ...

# %%
RnotinC.count()[0]
# Out:
# 32

# %%
## there are 32 companies which are present in rounds2 but not in comapnies.

# %% [markdown]
# ## 6. Merge the two data frames so that all variables (columns) in the company's frame are added to the rounds2 data frame. Name the merged frame master_dataframe. How many observations are present in master_frame ?

# %%
master_dataframe=pd.merge(left=companies,right=round2,
        left_on="permalink",right_on="company_permalink",
        how="outer")
master_dataframe.head()
# Out:
#                              permalink                    name  \
# 0                  /ORGANIZATION/-FAME                   #fame
# 1               /ORGANIZATION/-QOUNTER                :Qounter
# 2               /ORGANIZATION/-QOUNTER                :Qounter
# 3  /ORGANIZATION/-THE-ONE-OF-THEM-INC-  (THE) ONE of THEM,Inc.
# 4                /ORGANIZATION/0-6-COM                 0-6.com
#
#              homepage_url                                      category_list  \
# 0      http://livfame.com                                              Media
# 1  http://www.qounter.com  Application Platforms|Real Time|Social Network...
# 2  http://www.qounter.com  Application Platforms|Real Time|Social Network...
# 3     http://oneofthem.jp                                  Apps|Games|Mobile
# 4      http://www.0-6.com                                        Curated Web
#
#       status country_code state_code      region           city  founded_at  \
# ...

# %%
master_dataframe.shape
# Out:
# (114976, 16)

# %%
master_dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 114976 entries, 0 to 114975
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   permalink                114944 non-null  object
#  1   name                     114943 non-null  object
#  2   homepage_url             108810 non-null  object
#  3   category_list            111535 non-null  object
#  4   status                   114944 non-null  object
#  5   country_code             106271 non-null  object
#  6   state_code               104003 non-null  object
#  7   region                   104782 non-null  object
#  8   city                     104785 non-null  object
#  9   founded_at               94423 non-null   object
#  10  company_permalink        114949 non-null  object
#  11  funding_round_permalink  114949 non-null  object
#  12  funding_round_type       114949 non-null  object
# ...

# %% [markdown]
# # 7. Write the code to drop the redundant column ‘'company_permalink' from the master_dataframe.

# %%
master_dataframe.drop(columns="company_permalink").shape
# Out:
# (114976, 15)

# %% [markdown]
# ## 8. Write the code to find the percentage missing value (column-wise) in master_dataframe. Drop unnecessary columns.

# %%
percen=pd.DataFrame(((master_dataframe.isnull().sum())/master_dataframe.shape[0])*100)
percen
d1=percen.sort_values(by=0, ascending=False)
d1
# Out:
#                                  0
# funding_round_code       72.916087
# founded_at               17.875905
# raised_amount_usd        17.409720
# state_code                9.543731
# region                    8.866198
# city                      8.863589
# country_code              7.571145
# homepage_url              5.362858
# category_list             2.992798
# name                      0.028702
# permalink                 0.027832
# status                    0.027832
# company_permalink         0.023483
# funding_round_permalink   0.023483
# funding_round_type        0.023483
# funded_at                 0.023483

# %%
master_dataframe.drop(columns='funding_round_code').shape
# Out:
# (114976, 14)

# %%
# as funding round code has 72% of missing values in it. it can be dropped from the master dataframe.

# %% [markdown]
# ## 9. Create a pivot table to compare the mean and median values for ‘raised_amount_usd’ and ‘funding_round_type’ across different funding round categories..

# %%
data=pd.pivot_table(data=master_dataframe,index="funding_round_type",
         values=["raised_amount_usd"],aggfunc=["mean","median"])
data
# Out:
#                                    mean            median
#                       raised_amount_usd raised_amount_usd
# funding_round_type
# angel                      9.586945e+05          400000.0
# convertible_note           1.453439e+06          272000.0
# debt_financing             1.704353e+07         1100000.0
# equity_crowdfunding        5.383682e+05          100000.0
# grant                      4.300576e+06          201684.0
# non_equity_assistance      4.112031e+05           60000.0
# post_ipo_debt              1.687046e+08        19950000.0
# post_ipo_equity            8.218249e+07        12262852.5
# private_equity             7.330859e+07        20000000.0
# product_crowdfunding       1.363131e+06          183915.0
# secondary_market           7.964963e+07        32600000.0
# seed                       7.198180e+05          275000.0
# undisclosed                1.924237e+07         1018680.0
# venture                    1.174895e+07         5000000.0

# %%
sns.scatterplot(data)
plt.xticks(rotation=90)
plt.savefig('quest 9.png')

# %% [markdown]
# ## 10. Filter the master_dataframe on ‘raised_amount_usd’ such as ‘raised_amount_usd’ lie between 4 Millions to 15 Millions.

# %%
master_dataframe[(master_dataframe["raised_amount_usd"]>4000000) & (master_dataframe["raised_amount_usd"]>15000000)]
# Out:
#                          permalink                                 name  \
# 10            /ORGANIZATION/0XDATA                               H2O.ai
# 32           /ORGANIZATION/1000CHI  Beijing 1000CHI Software Technology
# 62          /ORGANIZATION/1010DATA                             1010data
# 73      /ORGANIZATION/10X-GENOMICS                         10X Genomics
# 80             /ORGANIZATION/117GO                                117go
# ...                            ...                                  ...
# 114906         /ORGANIZATION/ZYNGA                                Zynga
# 114907         /ORGANIZATION/ZYNGA                                Zynga
# 114910      /ORGANIZATION/ZYNGENIA                             Zyngenia
# 114951                         NaN                                  NaN
# 114956                         NaN                                  NaN
#
#                    homepage_url  \
# 10               http://h2o.ai/
# 32      http://www.1000chi.com/
# ...

# %% [markdown]
# ## 11.Identify the top 9 countries in terms of highest investment in ‘venture’ fund type.

# %%
d1=master_dataframe.sort_values("raised_amount_usd",ascending=False)
d1.set_index("funding_round_type",inplace=True)
d1.loc["venture"]
d2=d1.groupby("country_code")[["raised_amount_usd"]].sum()
d3=d2.sort_values(by="raised_amount_usd",ascending=False)
d4=d3.head(10)
d4
# Out:
#               raised_amount_usd
# country_code
# USA                6.694816e+11
# CHN                7.570357e+10
# GBR                3.276705e+10
# IND                2.768634e+10
# CAN                1.842468e+10
# RUS                1.127912e+10
# DEU                1.001774e+10
# ISR                9.713885e+09
# FRA                9.059771e+09
# NLD                5.966633e+09

# %%
sns.barplot(x=d4.index,y=d4['raised_amount_usd'])
plt.savefig('quest 11.png')

# %% [markdown]
# ## 12. Create the ‘main_category’ column by extracting the main sector using the column ‘category_list’. Hint - Use the Lambda function or string function.

# %%
master_dataframe["category_list"].fillna("Biotechnology",inplace=True)
master_dataframe["category_list"].isnull().sum()
# Out:
# 0

# %%
l=[]
for i in master_dataframe["category_list"].str.split("|").values:
    l.append(i[0])
l
# Out:
# ['Media',
#  'Application Platforms',
#  'Application Platforms',
#  'Apps',
#  'Curated Web',
#  'Software',
#  'Games',
#  'Biotechnology',
#  'Biotechnology',
#  'Analytics',
#  'Analytics',
#  'Analytics',
#  'Analytics',
#  'Mobile',
#  'Mobile',
#  'Mobile',
#  'E-Commerce',
#  'Entertainment',
#  'Networking',
#  'Health and Wellness',
#  'Health and Wellness',
#  'Internet Marketing',
#  'Apps',
#  'Entertainment',
#  'E-Commerce',
#  'E-Commerce',
#  'E-Commerce',
#  'E-Commerce',
#  'Education',
#  'Education',
#  'Search',
#  'Art',
#  'Mobile',
#  'Beauty',
#  'Curated Web',
#  'Curated Web',
#  'Curated Web',
#  'Curated Web',
#  'Curated Web',
#  'Curated Web',
#  'Curated Web',
#  'Curated Web',
#  'Curated Web',
#  'Curated Web',
#  'Curated Web',
#  'Local Businesses',
#  'Local Businesses',
#  'Local Businesses',
#  'Local Businesses',
#  'Local Businesses',
#  'Cosmetics',
#  'Games',
#  'Games',
#  'Games',
#  'Hospitality',
#  'Hospitality',
#  'Education',
# ...

# %%
master_dataframe["main_category"]=l
master_dataframe.head()
# Out:
#                              permalink                    name  \
# 0                  /ORGANIZATION/-FAME                   #fame
# 1               /ORGANIZATION/-QOUNTER                :Qounter
# 2               /ORGANIZATION/-QOUNTER                :Qounter
# 3  /ORGANIZATION/-THE-ONE-OF-THEM-INC-  (THE) ONE of THEM,Inc.
# 4                /ORGANIZATION/0-6-COM                 0-6.com
#
#              homepage_url                                      category_list  \
# 0      http://livfame.com                                              Media
# 1  http://www.qounter.com  Application Platforms|Real Time|Social Network...
# 2  http://www.qounter.com  Application Platforms|Real Time|Social Network...
# 3     http://oneofthem.jp                                  Apps|Games|Mobile
# 4      http://www.0-6.com                                        Curated Web
#
#       status country_code state_code      region           city  founded_at  \
# ...

# %% [markdown]
# ## 13. Using the user defined function convert the ‘rasied_amount_used’ column into a categorical column as followa)
# #### a)If the amount is less than 5 Millions then recode as TypeA.
# #### b) If the amount is greater than 5 Millions and less than 7 Millions then recode as TypeB.
# #### c) If the amount is greater than 7 Millions then recode as TypeC.

# %%
def type(x):
    if x< 5000000:
        return 'TypeA'
    elif 5000000 <= x < 7000000:
        return 'TypeB'
    else:
        return 'TypeC'

round2['raised_amount_usd']=round2['raised_amount_usd'].apply(lambda x: type(x))

# %%
round2.head()
# Out:
#                      company_permalink  \
# 0                  /ORGANIZATION/-FAME
# 1               /ORGANIZATION/-QOUNTER
# 2               /ORGANIZATION/-QOUNTER
# 3  /ORGANIZATION/-THE-ONE-OF-THEM-INC-
# 4                /ORGANIZATION/0-6-COM
#
#                            funding_round_permalink funding_round_type  \
# 0  /funding-round/9a01d05418af9f794eebff7ace91f638            venture
# 1  /funding-round/22dacff496eb7acb2b901dec1dfe5633            venture
# 2  /funding-round/b44fbb94153f6cdef13083530bb48030               seed
# 3  /funding-round/650b8f704416801069bb178a1418776b            venture
# 4  /funding-round/5727accaeaa57461bd22a9bdd945382d            venture
#
#   funding_round_code   funded_at raised_amount_usd
# 0                  B  05-01-2015             TypeC
# 1                  A  14-10-2014             TypeC
# 2                NaN  01-03-2014             TypeA
# 3                  B  30-01-2014             TypeA
# ...

# %% [markdown]
# # Extra questions

# %% [markdown]
# # 1. Find the percentage of null values is both table and visualize them.

# %%
companies.isnull().sum()/len(companies)*100
# Out:
# permalink         0.000000
# name              0.001507
# homepage_url      7.621143
# category_list     4.743250
# status            0.000000
# country_code     10.483968
# state_code       12.878194
# region           12.099204
# city             12.096191
# founded_at       22.934245
# dtype: float64

# %%
sns.heatmap(~companies.isnull(), cmap='magma')
plt.savefig('quest extra 1.png')

# %%
round2.isnull().sum()/len(round2)*100
# Out:
# company_permalink           0.000000
# funding_round_permalink     0.000000
# funding_round_type          0.000000
# funding_round_code         72.909725
# funded_at                   0.000000
# raised_amount_usd          17.390321
# dtype: float64

# %%
sns.heatmap(~round2.isnull())
plt.savefig('quest extra 1 2.png')

# %% [markdown]
# # 2. Fill the missing values in round2 table¶

# %%
round2["funding_round_code"].unique()
# Out:
# array(['B', 'A', nan, 'C', 'D', 'E', 'G', 'F', 'H'], dtype=object)

# %%
m=round2["funding_round_code"].mode()[0]
m
# Out:
# 'A'

# %%
round2["funding_round_code"].fillna(m,inplace=True)
round2
# Out:
#                                         company_permalink  \
# 0                                     /organization/-fame
# 1                                  /ORGANIZATION/-QOUNTER
# 2                                  /organization/-qounter
# 3                     /ORGANIZATION/-THE-ONE-OF-THEM-INC-
# 4                                   /organization/0-6-com
# ...                                                   ...
# 114944                          /organization/zzzzapp-com
# 114945                          /ORGANIZATION/ZZZZAPP-COM
# 114946                               /organization/ãeron
# 114947                             /ORGANIZATION/ÃASYS-2
# 114948  /organization/ä°novatiff-reklam-ve-tanä±tä±m-h...
#
#                                 funding_round_permalink funding_round_type  \
# 0       /funding-round/9a01d05418af9f794eebff7ace91f638            venture
# 1       /funding-round/22dacff496eb7acb2b901dec1dfe5633            venture
# ...

# %%
round2["raised_amount_usd"]=round2.groupby('funding_round_code')['raised_amount_usd'].apply(lambda x: x.fillna(x.median()))
# Out:
# C:\Users\telsm\AppData\Local\Temp\ipykernel_18120\833832551.py:1: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   round2["raised_amount_usd"]=round2.groupby('funding_round_code')['raised_amount_usd'].apply(lambda x: x.fillna(x.median()))

# %%
round2.isnull().sum()
# Out:
# company_permalink          0
# funding_round_permalink    0
# funding_round_type         0
# funding_round_code         0
# funded_at                  0
# raised_amount_usd          0
# dtype: int64

# %% [markdown]
# # 3. Find the top 3 investments,  in which the country and in which  field the company belongs,  in each year

# %%
l=[]  ## we have to split the year and make a new column
for i in round2["funded_at"].str.split("-"):
    l.append(int(i[2]))

# %%
round2["funded_year"]=l ## add year column

# %%
top3_investments = round2.groupby("funded_year").apply(lambda x: x.nlargest(3, "raised_amount_usd")).reset_index(drop=True)
top3_investments   ## finding top 3 investments in all years
# Out:
#                       company_permalink  \
# 0                   /ORGANIZATION/VEVEO
# 1               /ORGANIZATION/INTERCOMP
# 2    /ORGANIZATION/BUENA-PARK-LOCKSMITH
# 3                   /ORGANIZATION/APPLE
# 4                /ORGANIZATION/ABO-DATA
# ..                                  ...
# 101              /ORGANIZATION/SBERBANK
# 102               /ORGANIZATION/PING-AN
# 103                /ORGANIZATION/SUNING
# 104            /ORGANIZATION/DIDI-DACHE
# 105                  /ORGANIZATION/UBER
#
#                              funding_round_permalink funding_round_type  \
# 0    /funding-round/27711eabc8cea3f060c8c090c80852a7        undisclosed
# 1    /funding-round/518b5cd317f2bc768560d1a7bee2282c        undisclosed
# 2    /funding-round/4e0405b32707556e5cd4a3b5054f5672               seed
# 3    /funding-round/17f74f050394203dd6717c0faaf90c55               seed
# 4    /funding-round/809e211b969c3f66440fc15ffcd29385               seed
# ...

# %%
top3_investments.set_index('company_permalink', inplace=True)  # to get country and field merge with 
# companies so index change

# %%
top3_investments.head(2)
# Out:
#                                                  funding_round_permalink  \
# company_permalink
# /ORGANIZATION/VEVEO      /funding-round/27711eabc8cea3f060c8c090c80852a7
# /ORGANIZATION/INTERCOMP  /funding-round/518b5cd317f2bc768560d1a7bee2282c
#
#                         funding_round_type funding_round_code   funded_at  \
# company_permalink
# /ORGANIZATION/VEVEO            undisclosed                NaN  01-01-1960
# /ORGANIZATION/INTERCOMP        undisclosed                NaN  01-01-1971
#
#                          raised_amount_usd  funded_year
# company_permalink
# /ORGANIZATION/VEVEO                    NaN         1960
# /ORGANIZATION/INTERCOMP           549000.0         1971

# %%
companies["category_list"].fillna("Biotechnology",inplace=True)  ## nullvalue treated to avoid errors 
companies["category_list"].isnull().sum()
# Out:
# 0

# %%
l=[]
for i in companies["category_list"].str.split("|").values:
    l.append(i[0])
l                ### splitted category list to get the main category
# Out:
# ['Media',
#  'Application Platforms',
#  'Apps',
#  'Curated Web',
#  'Software',
#  'Games',
#  'Biotechnology',
#  'Analytics',
#  'Mobile',
#  'E-Commerce',
#  'Entertainment',
#  'Networking',
#  'Health and Wellness',
#  'Health and Wellness',
#  'Internet Marketing',
#  'Apps',
#  'Entertainment',
#  'E-Commerce',
#  'Education',
#  'Search',
#  'Art',
#  'Mobile',
#  'Beauty',
#  'Curated Web',
#  'Curated Web',
#  'Local Businesses',
#  'Cosmetics',
#  'Games',
#  'Hospitality',
#  'Education',
#  'Health Care',
#  'Analytics',
#  'Software',
#  'Advertising',
#  'Curated Web',
#  'Coffee',
#  'E-Commerce',
#  'Enterprise Software',
#  'Batteries',
#  'iOS',
#  'Biotechnology',
#  'Biotechnology',
#  'Software',
#  'Fashion',
#  'Health and Wellness',
#  'EdTech',
#  'Social Travel',
#  'Enterprise Software',
#  'Health and Wellness',
#  'Sports',
#  'Sports',
#  'Real Estate',
#  'Audio',
#  'Health Diagnostics',
#  'Advertising',
#  'E-Commerce',
#  'Biotechnology',
# ...

# %%
companies["main_category"]=l  ## addded main category as a new column

# %%
companies.set_index('permalink', inplace=True)   ## permalink as index to merge it with top3_investments

# %%
companies
# Out:
#                                                                                              name  \
# permalink
# /ORGANIZATION/-FAME                                                                         #fame
# /ORGANIZATION/-QOUNTER                                                                   :Qounter
# /ORGANIZATION/-THE-ONE-OF-THEM-INC-                                        (THE) ONE of THEM,Inc.
# /ORGANIZATION/0-6-COM                                                                     0-6.com
# /ORGANIZATION/004-TECHNOLOGIES                                                   004 Technologies
# ...                                                                                           ...
# /ORGANIZATION/ZZNODE-SCIENCE-AND-TECHNOLOGY-CO-LTD                  ZZNode Science and Technology
# /ORGANIZATION/ZZZZAPP-COM                                                   Zzzzapp Wireless ltd.
# ...

# %%
top3=top3_investments.join(companies, how='inner')
final=top3[['funded_year','main_category','country_code','raised_amount_usd','funding_round_type']].reset_index(drop=True)
df=final.sort_values(['funded_year','raised_amount_usd'], ascending=[False,False])
df.head(15)
# Out:
#      funded_year                  main_category country_code  \
# 85          2015                   Distributors          CHN
# 39          2015          Public Transportation          CHN
# 90          2015                     Automotive          USA
# 97          2014  Communications Infrastructure          USA
# 83          2014                        Banking          RUS
# 77          2014                        Banking          CHN
# 96          2013  Communications Infrastructure          USA
# 25          2013                  Biotechnology          USA
# 11          2013            Hardware + Software          CAN
# 95          2012  Communications Infrastructure          USA
# 6           2012                     E-Commerce          CHN
# 104         2012            Hardware + Software          USA
# 5           2011                     E-Commerce          CHN
# 43          2011                   All Students          USA
# ...

# %%
plt.figure(figsize=(20,10))
plt.subplot(1,3,1)
sns.scatterplot(x=df['funded_year'],y=df['raised_amount_usd'], hue=df['country_code'])

plt.subplot(1,3,3)
sns.scatterplot(y=df['main_category'],x=df['funded_year'], hue=df['funding_round_type'], color='purple')
plt.savefig('quest e extra.png')

# %% [markdown]
# # 4. write a program to find the details top 10 investments(including category and country) from a given year,  and then analyze the trend by dividing the given period inito 2 cebtuaries.

# %%
companies
# Out:
#                                                permalink  \
# 0                                    /ORGANIZATION/-FAME
# 1                                 /ORGANIZATION/-QOUNTER
# 2                    /ORGANIZATION/-THE-ONE-OF-THEM-INC-
# 3                                  /ORGANIZATION/0-6-COM
# 4                         /ORGANIZATION/004-TECHNOLOGIES
# ...                                                  ...
# 66363  /ORGANIZATION/ZZNODE-SCIENCE-AND-TECHNOLOGY-CO...
# 66364                          /ORGANIZATION/ZZZZAPP-COM
# 66365                               /ORGANIZATION/ÃERON
# 66366                             /ORGANIZATION/Ã”ASYS-2
# 66367  /ORGANIZATION/Ä°NOVATIFF-REKLAM-VE-TANÄ±TÄ±M-H...
#
#                                                 name  \
# 0                                              #fame
# 1                                           :Qounter
# 2                             (THE) ONE of THEM,Inc.
# 3                                            0-6.com
# ...

# %%
round2
# Out:
#                                         company_permalink  \
# 0                                     /ORGANIZATION/-FAME
# 1                                  /ORGANIZATION/-QOUNTER
# 2                                  /ORGANIZATION/-QOUNTER
# 3                     /ORGANIZATION/-THE-ONE-OF-THEM-INC-
# 4                                   /ORGANIZATION/0-6-COM
# ...                                                   ...
# 114944                          /ORGANIZATION/ZZZZAPP-COM
# 114945                          /ORGANIZATION/ZZZZAPP-COM
# 114946                               /ORGANIZATION/ÃERON
# 114947                             /ORGANIZATION/ÃASYS-2
# 114948  /ORGANIZATION/Ä°NOVATIFF-REKLAM-VE-TANÄ±TÄ±M-H...
#
#                                 funding_round_permalink funding_round_type  \
# 0       /funding-round/9a01d05418af9f794eebff7ace91f638            venture
# 1       /funding-round/22dacff496eb7acb2b901dec1dfe5633            venture
# ...

# %%
l=[]
for i in round2["funded_at"].str.split("-"):
    l.append(int(i[2]))

# %%
round2["funded_year"]=l

# %%
round2.head(2)
# Out:
#         company_permalink                          funding_round_permalink  \
# 0     /ORGANIZATION/-FAME  /funding-round/9a01d05418af9f794eebff7ace91f638
# 1  /ORGANIZATION/-QOUNTER  /funding-round/22dacff496eb7acb2b901dec1dfe5633
#
#   funding_round_type funding_round_code   funded_at  raised_amount_usd  \
# 0            venture                  B  05-01-2015         10000000.0
# 1            venture                  A  14-10-2014                NaN
#
#    funded_year
# 0         2015
# 1         2014

# %%
round2.set_index('company_permalink')
# Out:
#                                                                             funding_round_permalink  \
# company_permalink
# /ORGANIZATION/-FAME                                 /funding-round/9a01d05418af9f794eebff7ace91f638
# /ORGANIZATION/-QOUNTER                              /funding-round/22dacff496eb7acb2b901dec1dfe5633
# /ORGANIZATION/-QOUNTER                              /funding-round/b44fbb94153f6cdef13083530bb48030
# /ORGANIZATION/-THE-ONE-OF-THEM-INC-                 /funding-round/650b8f704416801069bb178a1418776b
# /ORGANIZATION/0-6-COM                               /funding-round/5727accaeaa57461bd22a9bdd945382d
# ...                                                                                             ...
# /ORGANIZATION/ZZZZAPP-COM                           /funding-round/8f6d25b8ee4199e586484d817bceda05
# /ORGANIZATION/ZZZZAPP-COM                           /funding-round/ff1aa06ed5da186c84f101549035d4ae
# ...

# %%
companies.set_index('permalink')
# Out:
#                                                                                              name  \
# permalink
# /ORGANIZATION/-FAME                                                                         #fame
# /ORGANIZATION/-QOUNTER                                                                   :Qounter
# /ORGANIZATION/-THE-ONE-OF-THEM-INC-                                        (THE) ONE of THEM,Inc.
# /ORGANIZATION/0-6-COM                                                                     0-6.com
# /ORGANIZATION/004-TECHNOLOGIES                                                   004 Technologies
# ...                                                                                           ...
# /ORGANIZATION/ZZNODE-SCIENCE-AND-TECHNOLOGY-CO-LTD                  ZZNode Science and Technology
# /ORGANIZATION/ZZZZAPP-COM                                                   Zzzzapp Wireless ltd.
# ...

# %%
data=companies.join(round2)  

# created a year column in round 2 
#companies.set_index('permalink')
# round2.set_index('company_permalink')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66368 entries, 0 to 66367
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   permalink                66368 non-null  object
#  1   name                     66367 non-null  object
#  2   homepage_url             61310 non-null  object
#  3   category_list            63220 non-null  object
#  4   status                   66368 non-null  object
#  5   country_code             59410 non-null  object
#  6   state_code               57821 non-null  object
#  7   region                   58338 non-null  object
#  8   city                     58340 non-null  object
#  9   founded_at               51147 non-null  object
#  10  company_permalink        66368 non-null  object
#  11  funding_round_permalink  66368 non-null  object
#  12  funding_round_type       66368 non-null  object
#  13  funding_round_code       17970 non-null  object
# ...

# %%
def max_2():
    a=int(input("Enter the starting year between(1960-2015): "))
    b=int(input("Enter the ending year between(1960-2015): "))
    if a in range(1960,2016):
        if b>a and b<2016:
            data
            df=data[(data["funded_year"]>a) & (data["funded_year"]<b)]
            df1=df.sort_values("raised_amount_usd",ascending=False)
            return df1.iloc[0:10,[0,3,5,12,16]]
        else:
            print("Enter the correct end value")
    else:
        print("Enter the correct start value")

# %%
max_2()
# Out:
# Enter the starting year between(1960-2015): 1996
# Enter the ending year between(1960-2015): 2000
#                                          permalink  \
# 45528                        /ORGANIZATION/PROPANC
# 45529                   /ORGANIZATION/PROPEL-FUELS
# 16022                           /ORGANIZATION/DMOD
# 32667                      /ORGANIZATION/LISNR-LLC
# 2880                    /ORGANIZATION/AMBIO-HEALTH
# 16469  /ORGANIZATION/DREAMWEAVER-INTERNATIONAL-INC
# 45659             /ORGANIZATION/PROTHERA-BIOLOGICS
# 44574                      /ORGANIZATION/PORTAFARE
# 63984                       /ORGANIZATION/WILOCITY
# 32668                         /ORGANIZATION/LISTAR
#
#                                            category_list country_code  \
# 45528                                      Biotechnology          AUS
# 45529                                   Clean Technology          USA
# 16022                      Intellectual Asset Management          USA
# ...

# %%
max_2() ## 20th centuary top 10 investments
# Out:
# Enter the starting year between(1960-2015): 1960
# Enter the ending year between(1960-2015): 2000
#                                          permalink  \
# 45528                        /ORGANIZATION/PROPANC
# 45529                   /ORGANIZATION/PROPEL-FUELS
# 16022                           /ORGANIZATION/DMOD
# 32667                      /ORGANIZATION/LISNR-LLC
# 2880                    /ORGANIZATION/AMBIO-HEALTH
# 16475                /ORGANIZATION/DRESDEN-SILICON
# 16469  /ORGANIZATION/DREAMWEAVER-INTERNATIONAL-INC
# 45659             /ORGANIZATION/PROTHERA-BIOLOGICS
# 44574                      /ORGANIZATION/PORTAFARE
# 63984                       /ORGANIZATION/WILOCITY
#
#                                category_list country_code funding_round_type  \
# 45528                          Biotechnology          AUS        undisclosed
# 45529                       Clean Technology          USA    post_ipo_equity
# ...

# %%
max_2() # 21st centuary
# Out:
# Enter the starting year between(1960-2015): 2000
# Enter the ending year between(1960-2015): 2015
#                                      permalink  \
# 37569          /ORGANIZATION/MY-COMPUTER-WORKS
# 16474         /ORGANIZATION/DREMIO-CORPORATION
# 60207                   /ORGANIZATION/UBMOBILE
# 35771         /ORGANIZATION/MICROPORT-SHANGHAI
# 18962                    /ORGANIZATION/EUNOMIC
# 21675             /ORGANIZATION/FRIENDLY-SCORE
# 20541     /ORGANIZATION/FIRSTHAND-TECHNOLOGIES
# 17355          /ORGANIZATION/EDISUN-HELIOSTATS
# 4368   /ORGANIZATION/ARROWPOINT-COMMUNICATIONS
# 18963               /ORGANIZATION/EUPHORIA-COM
#
#                                            category_list country_code  \
# 37569                                         Consulting          USA
# 16474                                           Software          USA
# 60207                                             Mobile          USA
# ...

# %% [markdown]
# ## 5. Convert the first rows to a dictionary inside a list

# %%
l1=[]
for i in range(0,10):
    l=[]
    for j in round2.columns:
        d={j:round2[j][i]}
        l.append(d)
    l1.append(l)

# %%
l1
# Out:
# [[{'company_permalink': '/ORGANIZATION/-FAME'},
#   {'funding_round_permalink': '/funding-round/9a01d05418af9f794eebff7ace91f638'},
#   {'funding_round_type': 'venture'},
#   {'funding_round_code': 'B'},
#   {'funded_at': '05-01-2015'},
#   {'raised_amount_usd': 10000000.0},
#   {'funded_year': 2015}],
#  [{'company_permalink': '/ORGANIZATION/-QOUNTER'},
#   {'funding_round_permalink': '/funding-round/22dacff496eb7acb2b901dec1dfe5633'},
#   {'funding_round_type': 'venture'},
#   {'funding_round_code': 'A'},
#   {'funded_at': '14-10-2014'},
#   {'raised_amount_usd': nan},
#   {'funded_year': 2014}],
#  [{'company_permalink': '/ORGANIZATION/-QOUNTER'},
#   {'funding_round_permalink': '/funding-round/b44fbb94153f6cdef13083530bb48030'},
#   {'funding_round_type': 'seed'},
#   {'funding_round_code': nan},
#   {'funded_at': '01-03-2014'},
#   {'raised_amount_usd': 700000.0},
#   {'funded_year': 2014}],
#  [{'company_permalink': '/ORGANIZATION/-THE-ONE-OF-THEM-INC-'},
# ...

# %% [markdown]
# # 6. what are the changes that we can observe  in top amount invested types, and invested categories before and after 2008 global economic crisis ?

# %%
data.head()
# Out:
#                              permalink                    name  \
# 0                  /ORGANIZATION/-FAME                   #fame
# 1               /ORGANIZATION/-QOUNTER                :Qounter
# 2  /ORGANIZATION/-THE-ONE-OF-THEM-INC-  (THE) ONE of THEM,Inc.
# 3                /ORGANIZATION/0-6-COM                 0-6.com
# 4       /ORGANIZATION/004-TECHNOLOGIES        004 Technologies
#
#                         homepage_url  \
# 0                 http://livfame.com
# 1             http://www.qounter.com
# 2                http://oneofthem.jp
# 3                 http://www.0-6.com
# 4  http://004gmbh.de/en/004-interact
#
#                                        category_list     status country_code  \
# 0                                              Media  operating          IND
# 1  Application Platforms|Real Time|Social Network...  operating          USA
# 2                                  Apps|Games|Mobile  operating          NaN
# ...

# %%
data1=data[data['funded_year']<2008]    ## data is merged dataset
invest=data1.groupby(['funding_round_type','category_list'])[['raised_amount_usd']].sum()
before=invest.sort_values(['raised_amount_usd'], ascending=False).head(10)
before.reset_index(inplace=True)    # topp 10 investments before 2008

# %%
before
# Out:
#   funding_round_type        category_list  raised_amount_usd
# 0            venture           Consulting       1.793607e+10
# 1    post_ipo_equity  Entertainment|Games       1.066494e+10
# 2            venture               Mobile       6.290693e+09
# 3        undisclosed             Software       5.085128e+09
# 4            venture             Software       4.737656e+09
# 5            venture        Biotechnology       4.159046e+09
# 6        undisclosed        Biotechnology       3.728624e+09
# 7            venture          Curated Web       1.546145e+09
# 8     debt_financing          Advertising       1.502500e+09
# 9            venture          Health Care       1.409936e+09

# %%
data1=data[data['funded_year']>2008]
invest3=data1.groupby(['funding_round_type','category_list'])[['raised_amount_usd']].sum()
after=invest3.sort_values(['raised_amount_usd'], ascending=False).head(10)
after.reset_index(inplace=True)  # top 10 investments after 2008

# %%
after
# Out:
#   funding_round_type                                     category_list  \
# 0            venture                                          Software
# 1            venture                                     Biotechnology
# 2            venture                                            Mobile
# 3     private_equity                                          Software
# 4     private_equity                                       Health Care
# 5            venture                                        E-Commerce
# 6            venture                               Enterprise Software
# 7            venture                                  Clean Technology
# 8      post_ipo_debt  Information Technology|Network Security|Software
# 9     debt_financing                            Information Technology
#
#    raised_amount_usd
# 0       1.298525e+10
# 1       1.238361e+10
# 2       5.612187e+09
# 3       5.387009e+09
# 4       4.346607e+09
# 5       4.345211e+09
# 6       4.181914e+09
# ...

# %% [markdown]
# # 7.According to the data which are favorable top 10 regions and countries  most favourable for investers in 20th and 21st centuary in terms of amount raised in the region?

# %%
data1=data[data['funded_year']<2000]
invest=data1.groupby(['region','country_code'])[['raised_amount_usd']].sum()
data20=invest.sort_values(['raised_amount_usd'], ascending=False).head(10)
data20    # 20th centuary favorable regions
# Out:
#                                        raised_amount_usd
# region                   country_code
# Melbourne                AUS                3.600000e+09
# Sacramento               USA                6.002000e+08
# SF Bay Area              USA                5.487353e+08
# Boston                   USA                2.982923e+08
# New York City            USA                2.328000e+08
# Cincinnati               USA                2.000000e+08
# Hartford                 USA                1.765000e+08
# Denver                   USA                1.551289e+08
# Dresden                  DEU                1.500000e+08
# Greenville - Spartanburg USA                1.200000e+08

# %%
data20
# Out:
#                                        raised_amount_usd
# region                   country_code
# Melbourne                AUS                3.600000e+09
# Sacramento               USA                6.002000e+08
# SF Bay Area              USA                5.487353e+08
# Boston                   USA                2.982923e+08
# New York City            USA                2.328000e+08
# Cincinnati               USA                2.000000e+08
# Hartford                 USA                1.765000e+08
# Denver                   USA                1.551289e+08
# Dresden                  DEU                1.500000e+08
# Greenville - Spartanburg USA                1.200000e+08

# %%
data1=data[data['funded_year']>=2000]
invest=data1.groupby(['region','country_code'])[['raised_amount_usd']].sum()
data21=invest.sort_values(['raised_amount_usd'], ascending=False).head(10)
data21  #21st centuary favourable regions
# Out:
#                                raised_amount_usd
# region           country_code
# SF Bay Area      USA                7.228305e+10
# New York City    USA                3.089791e+10
# Los Angeles      USA                2.953068e+10
# London           GBR                2.166073e+10
# Boston           USA                2.015608e+10
# Phoenix          USA                2.011660e+10
# Seattle          USA                8.682367e+09
# Chicago          USA                8.220381e+09
# Washington, D.C. USA                7.978049e+09
# Austin           USA                6.658283e+09

# %%
data21
# Out:
#                                raised_amount_usd
# region           country_code
# SF Bay Area      USA                7.228305e+10
# New York City    USA                3.089791e+10
# Los Angeles      USA                2.953068e+10
# London           GBR                2.166073e+10
# Boston           USA                2.015608e+10
# Phoenix          USA                2.011660e+10
# Seattle          USA                8.682367e+09
# Chicago          USA                8.220381e+09
# Washington, D.C. USA                7.978049e+09
# Austin           USA                6.658283e+09
